# %% [markdown]
# ## Lab 1- Python - tentatively due 2/21
#
# Let start with generating some fake random data. You can get a random number between 0 and 1 using the python random module as follow:

# %%
import random
x=random.random()
print "The Value of x is", x
# Out:
# The Value of x is 0.0294380285207

# %% [markdown]
# ### Exercise 1.1
# Using random, write a function GenerateData(N, mymin, mymax), that returns a python list containing N random numbers between specified minimum and maximum value. Note that you may want to quickly work out on paper how to turn numbers between 0 and 1 to between other values.

# %%
# Skeleton
import random
def GenerateData(N,min,max):
    out = []

    for i in range(N):
        num=((random.random()*(max-min))+min)
        #max-min gives the range in between, and multiplying that by the random number btw 0 and 1
        #means that that range is the max, when we add the min to it
        #...could just use random.random(min, max) but I think that defeats the purpose of the exercise
        out.append(num)
        
    return out

Data=GenerateData(1000,-10,10)
print "Data Type:", type(Data)
print "Data Length:", len(Data)
if len(Data)>0: 
    print "Type of Data Contents:", type(Data[0])
    print "Data Minimum:", min(Data)
    print "Data Maximum:", max(Data)
# Out:
#  Data Type: <type 'list'>
# Data Length: 1000
# Type of Data Contents: <type 'float'>
# Data Minimum: -9.98283542791
# Data Maximum: 9.98436837562

# %% [markdown]
# ### Exercise 1.2
#
# Write a function that computes the mean of values in a list.

# %%
# Skeleton
def mean(Data): #where Data is a list
    m=0
    
    for i in Data: m+=i   
    m=(m/len(Data))
    
    return m

print "Mean of Data:", mean(Data)
# Out:
# Mean of Data: 0.00125211282632

# %% [markdown]
# ### Exercise 1.3
#
# Write a function the applies a booling function (that returns true/false) to every element in data, and return a list of indices of elements where the result was true. Use this function to find the indices of positive entries.

# %%
def where(mylist,myfunc):
    out= []
    
    for i in range(len(mylist)): #gotta keep track of the indices
        if(myfunc(mylist[i])==True): #not sure about how the function interacts with the list
            out.append(i)
    
    return out

# %% [markdown]
# ### Exercise 1.4
#
# The inrange(mymin,mymax) function below returns a function that tests if it's input is between the specified values. Use this function, in conjunction to your solution to 1.3, to demonstrate that your data is "flat". Hint: pick several sub-ranges and show that the number of data point divided by the size of the range is roughly constant.

# %%
def inrange(mymin,mymax):
    def testrange(x):
        return x<mymax and x>=mymin
    return testrange

# Examples:
F1=inrange(0,10) #we made Data with 1000 values between -10 and 10, so theoretically, ~500 should pass this
F2=inrange(10,20) #and 0 should pass this

print F1(0), F1(1), F1(10), F1(15), F1(20)
print F2(0), F2(1), F2(10), F2(15), F2(20)

print "Number of Entries passing F1:", len(where(Data,F1))
print "Number of Entries passing F2:", len(where(Data,F2))
# Out:
# True True False False False
# False False True True False
# Number of Entries passing F1: 513
# Number of Entries passing F2: 0

# %% [markdown]
# ### Exercise 1.5
#
# Repeat Exercise 1.4 using the built in python functions filter, sum, and map instead of your solution to 1.3.

# %%
def inrange(mymin,mymax):
    def testrange(x):
        return x<mymax and x>=mymin
    return testrange

F1=inrange(0,10)
F2=inrange(10,20)

print "Number of entries passing F1:", len(filter(F1, Data))
print "Number of entries passing F2:", len(filter(F2, Data))
# Out:
# Number of entries passing F1: 513
# Number of entries passing F2: 0

# %% [markdown]
# ### Exercise 1.6
#
# Write a new function called GenerateDataFromFunction(N,mymin,mymax,myfunc), that instead of generating a flat distribution, generates a distribution with functional form coded in myfunc. Note that myfunc will always be > 0.
#
# Use your function to generate 1000 numbers that are Gaussian distributed, using the Gaussian function below. Confirm the mean of the data is close to mean you specify when building the Gaussian.
#
# Hint: A simple, but slow, solution is to a draw random number test_x within the specified range and another number p between the min and max of the function (which you will have to determine). If p<=function(test_x), then place test_x on the output. If not, repeat the process, drawing two new numbers. Repeat until you have the specified number of generated numbers, N. For this problem, it's OK to determine the min and max by numerically sampling the function.

# %%
import random

def GenerateDataFromFunction(N,mymin,mymax,myfunc):
    out = []
    
    count=0 #since not every number will be added
    fmin=1
    fmax=0
    for i in range(N):
        num=((random.random()*(mymax-mymin))+mymin)
        p=myfunc(num)
        #if(num<=fmin): fmin=num
        #if(num>=fmax): fmax=num
        if(p<=fmin): fmin=p
        if(p>=fmax): fmax=p
        #out.append(num)
    
    while(count<N):
        test_x=((random.random()*(mymax-mymin))+mymin)
        p=((random.random()*(fmax-fmin))+fmin)
        if(p<=myfunc(test_x)):
            out.append(test_x)
            count+=1
    
    print(fmin, fmax)
    return out

# %%
import math

def gaussian(mean, sigma):
    def f(x):
        return math.exp(((x-mean)**2)/(2*sigma**2))/math.sqrt(math.pi*sigma) 
    return f

# Example Instantiation
g1=gaussian(0,1)
g2=gaussian(10,3)

### BEGIN SOLUTION

GenerateDataFromFunction(1000, -1, 1, g1)

# Fill in your solution here        
    
### END SOLUTION
# Out:
# (0.5641897764780829, 0.9301581434656457)
# [-0.4753674835093493,
#  -0.7545044667258403,
#  0.9187713382943927,
#  0.927164515751205,
#  0.8894813957404843,
#  -0.7436162672463036,
#  -0.6691410152639514,
#  0.8164596360112455,
#  -0.7019155742672174,
#  -0.5650560798119717,
#  0.7925762518331907,
#  0.7769651658154182,
#  -0.6184232011472188,
#  0.9746399549096612,
#  -0.6942155055196249,
#  0.9916917025405212,
#  -0.7461387340001553,
#  -0.5605549985932077,
#  0.6887126575099645,
#  0.9049797904054366,
#  0.8548794690689068,
#  -0.3851325005933761,
#  -0.7294846234610466,
#  0.7347322612216494,
#  -0.917584772953195,
#  -0.9424823329200716,
#  0.34005076217317276,
#  -0.378199342304095,
#  0.9359891396860087,
#  -0.9524096709511958,
#  0.659241544163869,
#  -0.6984939616482757,
#  0.8815154723518459,
#  0.7686761184421527,
#  0.9765531707623765,
#  0.9705070034483514,
#  -0.771517618855653,
#  -0.877253875144905,
#  -0.7300721764672151,
#  -0.992647384246832,
#  0.6929650187720391,
#  0.9494392806934424,
#  0.6273541672040044,
#  -0.8522282612174794,
#  -0.8454270401934512,
#  -0.5961909808746675,
#  0.6963833318191601,
#  -0.7774570488854766,
#  -0.9311505895355467,
#  -0.7425292905949206,
